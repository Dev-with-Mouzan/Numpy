# %%
import numpy as np

# %%
array_missing_value=np.array([1,2,np.nan,4,5,np.nan,7])
array_missing_value
# Out:
# array([ 1.,  2., nan,  4.,  5., nan,  7.])

# %%
np.isnan(array_missing_value)
# Out:
# array([False, False,  True, False, False,  True, False])

# %%
np.nan_to_num(array_missing_value, nan=0)
# Out:
# array([1., 2., 0., 4., 5., 0., 7.])

# %%
# check infinte values
array_with_inf=np.array([1,2,np.inf,4,-np.inf,6])
np.isinf(array_with_inf)
# Out:
# array([False, False,  True, False,  True, False])
